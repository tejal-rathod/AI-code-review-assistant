# %%
import pandas as pd

df = pd.read_csv("dataset.csv")
print(df.head())

# Quick class distribution check
print(df["label"].value_counts())

# Ready for ML — encode labels
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["label_enc"] = le.fit_transform(df["label"])
# 0=hardcoded_secret, 1=insecure_api, 2=safe, 3=sql_injection
# Out:
#           id             label language  \
# 0  SAFE-0279              safe   python
# 1   API-0266      insecure_api     java
# 2   SQL-0102     sql_injection     java
# 3   SEC-0140  hardcoded_secret   nodejs
# 4   SQL-0059     sql_injection   python
#
#                                         code_snippet               source_id  \
# 0      import secrets; token = secrets.token_hex(32)           NVD-SAFE-4278
# 1  new ObjectInputStream(socket.getInputStream())...       NVD-CVE-2021-3265
# 2  String sql = "SELECT * FROM orders WHERE uid='...  OWASP-BENCHMARK-011101
# 3  process.env.JWT_SECRET = "hardcoded_jwt_secret...  OWASP-BENCHMARK-102139
# 4  cursor.execute("SELECT role FROM staff WHERE u...       NVD-CVE-2022-1058
#
#        cwe  severity                                        description  \
# 0      NaN      NONE  Secure coding practice: parameterised query / ...
# 1  CWE-502    MEDIUM  Insecure API usage: disabled TLS validation, u...
# 2   CWE-89  CRITICAL  Unsanitised user input concatenated directly i...
# 3  CWE-321  CRITICAL  Credential or secret key hardcoded in source code
# 4   CWE-89  CRITICAL  Unsanitised user input concatenated directly i...
#
#                                             fix_hint
# 0                                                NaN
# 1  Enable TLS verification, validate inputs, avoi...
# 2    Use parameterised queries / prepared statements
# 3  Store secrets in environment variables or a se...
# 4    Use parameterised queries / prepared statements
# label
# safe                300
# insecure_api        300
# sql_injection       300
# hardcoded_secret    300
# Name: count, dtype: int64
